-- %%
USE CATALOG maven_catalog;

-- %%
USE SCHEMA gold_schema;

-- %%
-- 1. Masking String PII Columns
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN full_name SET MASK pii_mask_policy;
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN customer_city SET MASK pii_mask_policy;
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN customer_state_province SET MASK pii_mask_policy;
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN customer_country SET MASK pii_mask_policy;
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN birthdate SET MASK pii_mask_policy;
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN yearly_income SET MASK pii_mask_policy;

-- 2. Masking Postal Code (Partial Mask)
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN customer_acct_num SET MASK custm_acc_partial_mask;

-- 3. Masking Numeric Income Columns 
-- (Note: Ensure numeric_mask_policy returns a DOUBLE or INT, not a STRING)
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_customers ALTER COLUMN yearly_income SET MASK numeric_mask_policy;

-- %%
-- DIM_PRODUCT masking (sensitive cost/profit)
ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_products
  ALTER COLUMN product_cost SET MASK numeric_mask_policy;

ALTER MATERIALIZED VIEW maven_catalog.gold_schema.dim_products
  ALTER COLUMN profit_amount SET MASK numeric_mask_policy;
