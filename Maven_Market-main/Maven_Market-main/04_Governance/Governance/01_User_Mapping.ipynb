-- %%
%sql
USE CATALOG maven_catalog;

-- %%
CREATE SCHEMA IF NOT EXISTS maven_catalog.governance;

-- %%
CREATE OR REPLACE TABLE maven_catalog.governance.region_manager_access (
    user_email STRING,
    allowed_sales_region STRING
);

-- %%
INSERT INTO maven_catalog.governance.region_manager_access (user_email, allowed_sales_region) VALUES
  ('samantha-northwest@namankandhari2003outlook.onmicrosoft.com',  'North West'),
  ('nolan_centralwest@namankandhari2003outlook.onmicrosoft.com',  'Central West'),
  ('paco-mexicocentral@namankandhari2003outlook.onmicrosoft.com',  'Mexico Central'),
  ('cassandra-canadawest@namankandhari2003outlook.onmicrosoft.com',  'Canada West'),
  ('malice-mexicosouth@namankandhari2003outlook.onmicrosoft.com',  'Mexico South'),
  ('kat-mexicowest@namankandhari2003outlook.onmicrosoft.com',  'Mexico West'),
  ('astra-southwest@namankandhari2003outlook.onmicrosoft.com',  'South West');

-- %%
SELECT * FROM maven_catalog.gold_schema.secured_fact_sales;

-- %%
select current_user()
