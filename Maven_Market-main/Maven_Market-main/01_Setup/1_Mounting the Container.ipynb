# %% [markdown]
# ###External Location

# %%
# %sql
GRANT READ FILES, WRITE FILES ON EXTERNAL LOCATION maven_external_location TO `data engineers`;
-- Hello testing cicd
-- Naman's test

# %%
# %sql
LIST 'abfss://mavenmarket@sgmavenmarkets.dfs.core.windows.net/'

# %% [markdown]
# ###Specifying Catalog and Schema

# %%
storage_account = 'sgmavenmarkets'
container = 'mavenmarket'
catalog = 'maven_catalog'
schema = 'bronze_schema'

# %%
# %sql
USE CATALOG maven_catalog

# %%
dbutils.secrets.listScopes()
